# %%
# !unzip classifier_training_colab_hw.zip #把老師建好的模組解壓縮
# !python ./classifier_training_colab_hw/training.py #並運行裡面的training.py , 會自動對負樣本(NEG)、正樣本(POS)進行訓練,並產出檔案 
#正樣本大小要是50*50(老師設定的框架)
#其中樣本文件 POS.txt > POS/00004.png 1 0 0 50 50 >> (檔名,圖片內的樣本數,x,y,w,h)
#xml - cascade是特徵文件
#做新訓練的話要把xml清空
# Out:
# Archive:  classifier_training_colab_hw.zip
#    creating: classifier_training_colab_hw/
#    creating: classifier_training_colab_hw/Data/
#   inflating: classifier_training_colab_hw/Data/Image0.jpg
#   inflating: classifier_training_colab_hw/Data/Image1.jpg
#   inflating: classifier_training_colab_hw/Data/Image2.jpg
#   inflating: classifier_training_colab_hw/Data/Image3.jpg
#   inflating: classifier_training_colab_hw/Data/Image4.jpg
#   inflating: classifier_training_colab_hw/Data/Image5.jpg
#   inflating: classifier_training_colab_hw/Data/Image6.jpg
#   inflating: classifier_training_colab_hw/Data/Image7.jpg
#   inflating: classifier_training_colab_hw/Data/Image8.jpg
#    creating: classifier_training_colab_hw/NEG/
#   inflating: classifier_training_colab_hw/NEG/00000.jpg
#   inflating: classifier_training_colab_hw/NEG/00001.jpg
#   inflating: classifier_training_colab_hw/NEG/00002.jpg
#   inflating: classifier_training_colab_hw/NEG/00003.jpg
# ...

# %%
from PIL import ImageFont, ImageDraw, Image
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
import time
target = "classifier_training_colab_hw/Data/Image{num}.jpg"
# print(target.format(num=1))
#用for跑每張目標物
for i in range(0,9,1):
  m1=cv2.imread(target.format(num=i),1) #Data裡面放的是要被辨識的目標,先讀取
  p1=cv2.CascadeClassifier("classifier_training_colab_hw/xml/cascade.xml") #分類器：控制變數=cv2.CascadeClassifier(分類器文件)
  ret=p1.detectMultiScale(m1,minNeighbors=6,minSize=(5,15)) #辨識目標：結果變數=控制變數.detectMultiScale(圖像變數,minNeighbors=檢測門檻數,minSize=最小尺寸)
  for x,y,w,h in ret: #用for把每個標示物標記起來
    cv2.rectangle(m1, (x,y), (x+w,y+h), (0,0,255), 2)
  cv2_imshow(m1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pwd #查看当前所在路径
# !ls #查看当前目录的所有文件名称
# Out:
# /content
# classifier_training_colab_hw	       sample_data
# classifier_training_colab_hw_done.zip

# %%
#壓縮文件,以便下載
# !zip -r /content/classifier_training_colab_hw_done.zip /content/classifier_training_colab_hw
# Out:
#   adding: content/classifier_training_colab_hw/ (stored 0%)
#   adding: content/classifier_training_colab_hw/Data/ (stored 0%)
#   adding: content/classifier_training_colab_hw/Data/Image4.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/Data/Image7.jpg (deflated 1%)
#   adding: content/classifier_training_colab_hw/Data/Image6.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/Data/Image5.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/Data/Image3.jpg (deflated 2%)
#   adding: content/classifier_training_colab_hw/Data/Image8.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/Data/Image1.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/Data/Image2.jpg (deflated 1%)
#   adding: content/classifier_training_colab_hw/Data/Image0.jpg (deflated 0%)
#   adding: content/classifier_training_colab_hw/xml/ (stored 0%)
#   adding: content/classifier_training_colab_hw/xml/cascade.xml (deflated 76%)
# ...

# %%
from google.colab import files
files.download("/content/classifier_training_colab_hw_done.zip")
